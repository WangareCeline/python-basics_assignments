# %%
# Write a function greet(name) that prints “Hello, [name]”.
def greet(name):
    print(f"Hello. {name}")


greet("Celine")
# Out:
# Hello. Celine

# %%
# Create a function add(a, b) that returns the sum.
def add(a,b):
    print(f"Sum is {a+b}")


add(10,34)
# Out:
# Sum is 44

# %%
# Modify add() to print “even” or “odd” based on the result.
def add(a,b):
    sum = a+b
    if sum%2 == 0:
        print(f"Sum is {sum} which is an Even number")
    else:
        print(f"Sum is {sum} which is an odd number")


add(10,34)
# Out:
# Sum is 44 which is an Even number

# %%
# Call a function from within another function.
def add(a,b):
    sum = a+b
    def check_even(result):
        if sum%2 == 0:
            print(f"Sum is {sum} which is an Even number")
        else:
            print(f"Sum is {sum} which is an odd number")
    check_even(sum)

add(10,34)
# Out:
# Sum is 44 which is an Even number

# %%
# Write a calculator function:
# Takes two numbers and an operation (+, -, *, /)
# Returns the result

a = float(input("Enter the first number:    "))
operation = input("What mathematical operation do you want to perform. signs only, (+, -, *, /):    ")
b = float(input("Enter the second number:    "))

def calculator(a,b,operation):
    if operation == '+':
        print(f"{a} + {b} = {a+b}")
    elif operation == '-':
        print(f"{a} - {b} = {a-b}")
    elif operation == '*':
        print(f"{a} * {b} = {a*b}")
    elif operation == '/':
        print(f"{a} / {b} = {a/b}")


calculator(a,b,operation)
# Out:
# 45.0 * 5.0 = 225.0
